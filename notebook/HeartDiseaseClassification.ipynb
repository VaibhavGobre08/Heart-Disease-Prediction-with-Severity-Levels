# %%
# Importing the 'files' module from the 'google.colab' library
from google.colab import files

# Prompting the user to upload files from their local machine to the Colab environment
uploaded = files.upload()

# Storing the uploaded files in the 'uploaded' variable as a dictionary
# The keys of the dictionary are the filenames, and the values are the contents of the files
# Out:
#      <input type="file" id="files-f725c50e-84fa-4035-a410-9e0436bbd733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f725c50e-84fa-4035-a410-9e0436bbd733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importing the pandas library and aliasing it as 'pd'
import pandas as pd

# Importing the seaborn library and aliasing it as 'sns'
import seaborn as sns

# Importing the matplotlib.pyplot module and aliasing it as 'plt'
import matplotlib.pyplot as plt

# Importing the train_test_split function from the sklearn.model_selection module
from sklearn.model_selection import train_test_split

# Importing classification_report, confusion_matrix, and accuracy_score functions from the sklearn.metrics module
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Importing the RandomForestClassifier class from the sklearn.ensemble module
from sklearn.ensemble import RandomForestClassifier

# %%
# Importing the pandas library and aliasing it as 'pd'
import pandas as pd

# Reading a CSV file named 'heart.csv' into a pandas DataFrame named 'df'
df = pd.read_csv('heart.csv')

# %%
# Assuming 'df' is a pandas DataFrame object

# Using the 'shape' attribute of the DataFrame to get the dimensions (number of rows and columns)
# This returns a tuple where the first element represents the number of rows and the second element represents the number of columns
df_shape = df.shape

# Printing the shape of the DataFrame
print("Shape of the DataFrame:")
print("Number of rows:", df_shape[0])  # Accessing the first element of the tuple (number of rows)
print("Number of columns:", df_shape[1])  # Accessing the second element of the tuple (number of columns)
# Out:
# Shape of the DataFrame:
# Number of rows: 1025
# Number of columns: 14

# %%
# Extracting the 'target' column from the DataFrame 'df'
values_count = df['target']

# Counting the occurrences of each unique value in the 'target' column
value_counts = values_count.value_counts()

# Printing the count of each unique value
print(value_counts)

# Creating a count plot using seaborn to visualize the distribution of values in the 'target' column
sns.countplot(values_count)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %%
# Creating a boolean mask 'risk' where the value is True if the 'target' column in the DataFrame 'df' is equal to 1
risk = df['target'] == 1

# Creating a copy of the DataFrame 'df' and assigning it to the variable 'tem'
tem = df.copy()

# Using the 'where' method of the DataFrame 'tem' to replace values where 'risk' is False with NaN
# inplace=True modifies the DataFrame 'tem' in place rather than returning a new DataFrame
tem.where(risk, inplace=True)

# %%
# Plotting a histogram of the 'age' column from the DataFrame 'tem'
plt.hist(tem.age, bins=20, histtype='bar', rwidth=0.9, color='blue')

# Adding a title to the plot
plt.title('Heart Diseases Frequency for Ages')

# Labeling the x-axis
plt.xlabel('Age')

# Labeling the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'sex' and 'target' columns from DataFrame 'df' and plotting it as a bar chart
pd.crosstab(df.sex, df.target).plot(kind="bar", figsize=(20, 10))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for Sex')

# Defining the labels for the x-axis and y-axis
sex = ['female', 'male']
plt.xlabel('Sex')
plt.ylabel('Frequency')

# Rotating the x-axis labels for better readability
plt.xticks(rotation=90)

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'cp' (chest pain) and 'target' (heart disease presence) columns in the DataFrame 'df',
# and plotting it as a bar chart
pd.crosstab(df.cp, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for Chest Pain')

# Adding a label to the x-axis
plt.xlabel('Chest Pain')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot to differentiate between heart disease risk categories
plt.legend(["No risk of heart disease", "Risk of heart disease"])

# Displaying the plot
plt.show()

# %%
import numpy as np

# Generate 14 distinct colors
colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'cyan', 'magenta', 'brown', 'pink', 'gray', 'olive', 'teal', 'navy']

# Plotting a histogram of 'tem' with specified parameters and using the list of colors
plt.hist(tem, bins=20, histtype='bar', rwidth=0.9, color=colors)

# Adding a title to the plot
plt.title('Heart Diseases Frequency for resting blood pressure')

# Adding a label to the x-axis
plt.xlabel('Blood Pressure')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Plotting a histogram of 'tem.exang' with specified parameters
plt.hist(tem.exang, bins=20, histtype='bar', rwidth=0.9, color='red')

# Adding a title to the plot
plt.title('Heart Diseases Frequency for exercise induced angina')

# Adding a label to the x-axis
plt.xlabel('Serum Cholestoral')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.fbs' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.fbs, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for fasting blood sugar')

# Adding a label to the x-axis
plt.xlabel('Fasting Blood Sugar')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.restecg' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.restecg, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for resting electrocardiographic')

# Adding a label to the x-axis
plt.xlabel('Resting Electrocardiographic')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.thalach' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.thalach, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for maximum heart rate')

# Adding a label to the x-axis
plt.xlabel('Maximum Heart Rate')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.exang' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.exang, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for exercise induced angina')

# Adding a label to the x-axis
plt.xlabel('Exercise-induced angina')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.oldpeak' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.oldpeak, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for ST depression')

# Adding a label to the x-axis
plt.xlabel('Oldpeak')

# Adding a label to the y-axis
plt.ylabel('ST depression')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.slope' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.slope, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for slope of the peak exercise')

# Adding a label to the x-axis
plt.xlabel('Slope')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.ca' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.ca, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for number of major vessels colored by fluoroscopy')

# Adding a label to the x-axis
plt.xlabel('Major Vessels Colored by Fluoroscopy')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Creating a cross-tabulation of 'df.thal' and 'df.target' and plotting it as a bar chart
pd.crosstab(df.thal, df.target).plot(kind="bar", figsize=(20, 6))

# Adding a title to the plot
plt.title('Heart Diseases Frequency for thalassemia')

# Adding a label to the x-axis
plt.xlabel('Thalassemia')

# Adding a label to the y-axis
plt.ylabel('Frequency')

# Adding a legend to the plot
plt.legend(["Do not have risk of heart disease", "Have risk of heart disease"])

# Displaying the plot
plt.show()

# %%
# Displaying the first few rows of the DataFrame 'df'
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Generating descriptive statistics summary for the DataFrame 'df'
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# Displaying a concise summary of the DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# Calculating the absolute correlation coefficients between the 'target' column and other columns in the DataFrame 'df'
correlation = df.corr()["target"].abs()

# Printing the correlation coefficients
print(correlation)
# Out:
# age         0.229324
# sex         0.279501
# cp          0.434854
# trestbps    0.138772
# chol        0.099966
# fbs         0.041164
# restecg     0.134468
# thalach     0.422895
# exang       0.438029
# oldpeak     0.438441
# slope       0.345512
# ca          0.382085
# thal        0.337838
# target      1.000000
# Name: target, dtype: float64

# %%
# Splitting the DataFrame into features (X) and target (y) variables using train_test_split
# X contains all columns except the last one (features)
# y contains the last column (target)
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :-1], df['target'], test_size=0.2, random_state=0)

# Printing the shape of the training set features
print(X_train.shape)

# Printing the shape of the test set features
print(X_test.shape)
# Out:
# (820, 13)
# (205, 13)

# %%
# Displaying the first few rows of the training set features (X_train)
X_train.head()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 315    42    1   3       148   244    0        0      178      0      0.8
# 204    66    0   2       146   278    0        0      152      0      0.0
# 363    53    1   2       130   246    1        0      173      0      0.0
# 5      58    0   0       100   248    0        0      122      0      1.0
# 1017   53    1   0       123   282    0        1       95      1      2.0
#
#       slope  ca  thal
# 315       2   2     2
# 204       1   1     2
# 363       2   3     2
# 5         1   0     2
# 1017      1   2     3

# %%
# Importing the Gaussian Naive Bayes classifier from sklearn
from sklearn.naive_bayes import GaussianNB

# Creating an instance of the Gaussian Naive Bayes classifier
gnb = GaussianNB()

# Training the Gaussian Naive Bayes classifier on the training data
gnb.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = gnb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, roc_curve, RocCurveDisplay, ConfusionMatrixDisplay

# Train the classifier
gnb.fit(X_train, y_train)

# Make predictions
pred = gnb.predict(X_test)

# Compute confusion matrix
cm = confusion_matrix(y_test, pred)

# Plot confusion matrix (trade-off)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=gnb.classes_).plot()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, pred)

# Plot ROC curve (error plot)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)
roc_display.plot()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %%
# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        98
#            1       0.83      0.90      0.86       107
#
#     accuracy                           0.85       205
#    macro avg       0.86      0.85      0.85       205
# weighted avg       0.86      0.85      0.85       205
#
# Confusion Matrix:
#  [[79 19]
#  [11 96]]
# Accuracy:  0.8536585365853658

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

# Importing the Multinomial Naive Bayes classifier from sklearn
from sklearn.naive_bayes import MultinomialNB

# Creating an instance of the Multinomial Naive Bayes classifier
gnb = MultinomialNB()

# Training the Multinomial Naive Bayes classifier on the training data
gnb.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = gnb.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))

# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(gnb, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis
alpha_values = [0.1, 1, 10]  # Example alpha values to analyze
for alpha in alpha_values:
    gnb = MultinomialNB(alpha=alpha)
    gnb.fit(X_train, y_train)
    pred = gnb.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    print(f'Alpha={alpha}: Accuracy={accuracy}')

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, gnb.predict_proba(X_test)[:, 1])
roc_auc = roc_auc_score(y_test, gnb.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77        98
#            1       0.78      0.80      0.79       107
#
#     accuracy                           0.78       205
#    macro avg       0.78      0.78      0.78       205
# weighted avg       0.78      0.78      0.78       205
#
# Confusion Matrix:
#  [[74 24]
#  [21 86]]
# Accuracy:  0.7804878048780488
# Alpha=0.1: Accuracy=0.7804878048780488
# Alpha=1: Accuracy=0.7804878048780488
# Alpha=10: Accuracy=0.775609756097561

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

# Importing the Bernoulli Naive Bayes classifier from sklearn
from sklearn.naive_bayes import BernoulliNB

# Creating an instance of the Bernoulli Naive Bayes classifier
gnb = BernoulliNB()

# Training the Bernoulli Naive Bayes classifier on the training data
gnb.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = gnb.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))

# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(gnb, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis
alpha_values = [0.1, 1, 10]  # Example alpha values to analyze
for alpha in alpha_values:
    gnb = BernoulliNB(alpha=alpha)
    gnb.fit(X_train, y_train)
    pred = gnb.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    print(f'Alpha={alpha}: Accuracy={accuracy}')

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, gnb.predict_proba(X_test)[:, 1])
roc_auc = roc_auc_score(y_test, gnb.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83        98
#            1       0.83      0.89      0.86       107
#
#     accuracy                           0.84       205
#    macro avg       0.85      0.84      0.84       205
# weighted avg       0.85      0.84      0.84       205
#
# Confusion Matrix:
#  [[78 20]
#  [12 95]]
# Accuracy:  0.8439024390243902
# Alpha=0.1: Accuracy=0.8439024390243902
# Alpha=1: Accuracy=0.8439024390243902
# Alpha=10: Accuracy=0.8439024390243902

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C = 2 , solver = 'liblinear')
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
print(classification_report(y_test , pred))

print()
print("Confusion  Matrixs : \n", confusion_matrix(y_test,pred))
print('Accuracy : ', accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        98
#            1       0.83      0.93      0.88       107
#
#     accuracy                           0.86       205
#    macro avg       0.87      0.86      0.86       205
# weighted avg       0.87      0.86      0.86       205
#
#
# Confusion  Matrixs :
#  [[ 77  21]
#  [  7 100]]
# Accuracy :  0.8634146341463415

# %%
# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(clf, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis
C_values = [0.1, 1, 10]  # Example C values to analyze
for C in C_values:
    clf = LogisticRegression(C=C, solver='liblinear')
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    print(f'C={C}: Accuracy={accuracy}')

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, clf.predict_proba(X_test)[:, 1])
roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# C=0.1: Accuracy=0.8634146341463415
# C=1: Accuracy=0.8682926829268293
# C=10: Accuracy=0.8634146341463415

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import learning_curve
from sklearn import svm

# Creating an instance of the Support Vector Classifier (SVC)
svc = svm.SVC(kernel='linear', C=1)

# Training the SVC classifier on the training data
svc.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = svc.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))

# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(svc, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis
C_values = [0.1, 1, 10]  # Example C values to analyze
for C_value in C_values:
    svc = svm.SVC(kernel='linear', C=C_value)
    svc.fit(X_train, y_train)
    pred = svc.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    print(f'C={C_value}: Accuracy={accuracy}')

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, svc.decision_function(X_test))
roc_auc = roc_auc_score(y_test, svc.decision_function(X_test))

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        98
#            1       0.80      0.92      0.86       107
#
#     accuracy                           0.84       205
#    macro avg       0.85      0.84      0.84       205
# weighted avg       0.85      0.84      0.84       205
#
# Confusion Matrix:
#  [[74 24]
#  [ 9 98]]
# Accuracy:  0.8390243902439024
# C=0.1: Accuracy=0.8634146341463415
# C=1: Accuracy=0.8390243902439024
# C=10: Accuracy=0.8536585365853658

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import learning_curve
from sklearn import svm

# Creating an instance of the SVM classifier with the RBF kernel and regularization parameter C=1
svc = svm.SVC(kernel='rbf', C=1)

# Training the SVM classifier on the training data
svc.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = svc.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))

# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(svc, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis
# SVM with RBF kernel has a trade-off between regularization parameter C and model complexity
C_values = [0.1, 1, 10]  # Example C values to analyze
for C in C_values:
    svc = svm.SVC(kernel='rbf', C=C)
    svc.fit(X_train, y_train)
    pred = svc.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    print(f'C={C}: Accuracy={accuracy}')

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, svc.decision_function(X_test))
roc_auc = roc_auc_score(y_test, svc.decision_function(X_test))

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72        98
#            1       0.73      0.81      0.77       107
#
#     accuracy                           0.75       205
#    macro avg       0.75      0.74      0.74       205
# weighted avg       0.75      0.75      0.74       205
#
# Confusion Matrix:
#  [[66 32]
#  [20 87]]
# Accuracy:  0.7463414634146341
# C=0.1: Accuracy=0.6536585365853659
# C=1: Accuracy=0.7463414634146341
# C=10: Accuracy=0.7804878048780488

# %%
# Importing necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import learning_curve, validation_curve
import numpy as np
import matplotlib.pyplot as plt

# Importing Support Vector Classifier (SVC) from sklearn
from sklearn import svm

# Creating an instance of the Support Vector Classifier with polynomial kernel and C=1
svc = svm.SVC(kernel='poly', C=1, probability=True)

# Training the SVC classifier on the training data
svc.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = svc.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))

# Error Plot (Learning Curve)
train_sizes, train_scores, test_scores = learning_curve(svc, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# Trade-off Analysis (Validation Curve)
param_range = np.logspace(-3, 3, 5)  # Example range for parameter C
train_scores, test_scores = validation_curve(
    svc, X_train, y_train, param_name="C", param_range=param_range,
    cv=5, scoring="accuracy", n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(param_range, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(param_range, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(param_range, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(param_range, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xscale('log')
plt.xlabel('Parameter C')
plt.ylabel('Accuracy')
plt.title('Trade-off Analysis (Validation Curve)')
plt.legend()
plt.grid()
plt.show()

# ROC Curve
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, svc.predict_proba(X_test)[:, 1])
roc_auc = roc_auc_score(y_test, svc.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.74        98
#            1       0.75      0.78      0.76       107
#
#     accuracy                           0.75       205
#    macro avg       0.75      0.75      0.75       205
# weighted avg       0.75      0.75      0.75       205
#
# Confusion Matrix:
#  [[71 27]
#  [24 83]]
# Accuracy:  0.751219512195122

# %%
# Importing RandomForestClassifier from sklearn
from sklearn.ensemble import RandomForestClassifier

# Creating an instance of the RandomForestClassifier with specified parameters
classifier_rf = RandomForestClassifier(criterion='entropy', max_depth=10,
                                        n_estimators=140, min_samples_leaf=3, min_samples_split=10)

# Training the RandomForestClassifier on the training data
classifier_rf.fit(X_train, y_train)

# Making predictions on the test data using the trained classifier
pred = classifier_rf.predict(X_test)

# Printing the classification report
print(classification_report(y_test, pred))

# Printing the confusion matrix
print("Confusion Matrix: \n", confusion_matrix(y_test, pred))

# Printing the accuracy score
print('Accuracy: ', accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        98
#            1       0.98      1.00      0.99       107
#
#     accuracy                           0.99       205
#    macro avg       0.99      0.99      0.99       205
# weighted avg       0.99      0.99      0.99       205
#
# Confusion Matrix:
#  [[ 96   2]
#  [  0 107]]
# Accuracy:  0.9902439024390244

# %%
# Importing necessary libraries
from sklearn.metrics import roc_curve, RocCurveDisplay

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, pred)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# Error Plot (Learning Curve)
# Note: RandomForestClassifier does not have a built-in learning_curve function like some other classifiers,
# so you may need to implement the learning curve manually or use third-party libraries like yellowbrick.
# Here, I'll provide a simplified version of how to visualize the learning curve using scikit-learn's learning_curve function.

from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(classifier_rf, X_train, y_train, cv=5, scoring='accuracy')
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.grid()
plt.show()

# %%
import pickle

# Save the trained RandomForestClassifier model to a file named 'rainforest_model.sav'
filename = 'rainforest_model.sav'
pickle.dump(classifier_rf, open(filename, 'wb'))

# %%
import pickle

# Load the trained RandomForestClassifier model from the saved file 'rainforest_model.sav'
loaded_model = pickle.load(open('rainforest_model.sav', 'rb'))

# Evaluate the loaded model on the test data and print the accuracy score
print(loaded_model.score(X_test, y_test))
# Out:
# 0.9902439024390244

# %%
# Dictionary containing model names and their corresponding accuracies
data = {'LogisticRegression': 85.24, 'Naive Bayes': 85.24, 'SVM': 81.96, 'Random Forest': 88.52}

# Extracting model names and accuracy values from the dictionary
models = list(data.keys())
accuracies = list(data.values())

# Creating a figure for plotting
fig = plt.figure(figsize=(10, 5))

# Creating the bar plot
plt.bar(models, accuracies, width=0.4)

# Adding labels and title to the plot
plt.xlabel("Model Name")
plt.ylabel("Accuracy")
plt.title("Comparison of Different Models")

# Displaying the plot
plt.show()
